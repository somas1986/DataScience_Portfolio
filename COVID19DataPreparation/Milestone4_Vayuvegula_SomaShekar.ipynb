# %%
#importing libraries
import numpy as np
import pandas as pd
import requests
import json
from scipy import stats

# %%
# base url
url = "https://api.covid19api.com/summary"

# %%
covidResponse = requests.request("GET", url)

print(covidResponse.text)
# Out:
# {"ID":"e91b0893-ff87-4152-904b-2bd787460a59","Message":"","Global":{"NewConfirmed":193019,"TotalConfirmed":630912233,"NewDeaths":526,"TotalDeaths":6594405,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z"},"Countries":[{"ID":"0b096549-975a-46db-be84-1895d73dfaf7","Country":"Afghanistan","CountryCode":"AF","Slug":"afghanistan","NewConfirmed":77,"TotalConfirmed":203574,"NewDeaths":1,"TotalDeaths":7826,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"ceb74727-4765-46cc-b538-088efb38e47f","Country":"Albania","CountryCode":"AL","Slug":"albania","NewConfirmed":19,"TotalConfirmed":333046,"NewDeaths":0,"TotalDeaths":3593,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"fb7c55ee-39f2-4d6d-be32-dc254b0fd257","Country":"Algeria","CountryCode":"DZ","Slug":"algeria","NewConfirmed":6,"TotalConfirmed":270862,"NewDeaths":0,"TotalDeaths":6881,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"871a411f-2668-41b2-b9c6-37353f86034f","Country":"Andorra","CountryCode":"AD","Slug":"andorra","NewConfirmed":0,"TotalConfirmed":46588,"NewDeaths":0,"TotalDeaths":155,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"02aaaa78-138a-462c-8059-2f78065990f0","Country":"Angola","CountryCode":"AO","Slug":"angola","NewConfirmed":0,"TotalConfirmed":103131,"NewDeaths":0,"TotalDeaths":1917,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"1a4c8291-bd3e-4765-ad5b-a77d8dbc7d8b","Country":"Antarctica","CountryCode":"AQ","Slug":"antarctica","NewConfirmed":0,"TotalConfirmed":11,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"ddcb5dbf-a667-463e-8cb7-66688eca7aad","Country":"Antigua and Barbuda","CountryCode":"AG","Slug":"antigua-and-barbuda","NewConfirmed":0,"TotalConfirmed":9106,"NewDeaths":0,"TotalDeaths":146,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"06589228-670a-49af-a450-717bad44fa1d","Country":"Argentina","CountryCode":"AR","Slug":"argentina","NewConfirmed":0,"TotalConfirmed":9718875,"NewDeaths":0,"TotalDeaths":129991,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"e42e5253-a234-497e-9c36-094bcf46a9a9","Country":"Armenia","CountryCode":"AM","Slug":"armenia","NewConfirmed":0,"TotalConfirmed":445242,"NewDeaths":0,"TotalDeaths":8709,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"bc197fda-6c51-4ba2-8e45-543bf079b067","Country":"Australia","CountryCode":"AU","Slug":"australia","NewConfirmed":1713,"TotalConfirmed":10418986,"NewDeaths":0,"TotalDeaths":15786,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"a6e7b1eb-b9d8-410c-a624-868162778e2a","Country":"Austria","CountryCode":"AT","Slug":"austria","NewConfirmed":4307,"TotalConfirmed":5462911,"NewDeaths":7,"TotalDeaths":21036,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"3f8af6f0-056b-4217-9e28-015a64dc2a40","Country":"Azerbaijan","CountryCode":"AZ","Slug":"azerbaijan","NewConfirmed":27,"TotalConfirmed":823496,"NewDeaths":2,"TotalDeaths":9955,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"c0aff4a2-b04e-42e9-bc8a-07fd3b00f3c4","Country":"Bahamas","CountryCode":"BS","Slug":"bahamas","NewConfirmed":0,"TotalConfirmed":37386,"NewDeaths":0,"TotalDeaths":833,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"a2e01b05-c1e3-4c2a-9b0f-5f86940e4987","Country":"Bahrain","CountryCode":"BH","Slug":"bahrain","NewConfirmed":209,"TotalConfirmed":691509,"NewDeaths":0,"TotalDeaths":1529,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-11-06T22:55:06.135Z","Premium":{}},{"ID":"d517aaae-fd64-4a93-a241-be7c15cca4b9","Country":"Bangladesh","CountryCode ...

# %%
#Convert Text to JSON
covid_json=json.loads(covidResponse.text)

# %%
# creating the dataframe
df_covid=pd.DataFrame()

# %%
json_countries = covid_json['Countries']

# %%
json_countries
# Out:
# [{'ID': '0b096549-975a-46db-be84-1895d73dfaf7',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 77,
#   'TotalConfirmed': 203574,
#   'NewDeaths': 1,
#   'TotalDeaths': 7826,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ceb74727-4765-46cc-b538-088efb38e47f',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 19,
#   'TotalConfirmed': 333046,
#   'NewDeaths': 0,
#   'TotalDeaths': 3593,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'fb7c55ee-39f2-4d6d-be32-dc254b0fd257',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 6,
#   'TotalConfirmed': 270862,
#   'NewDeaths': 0,
#   'TotalDeaths': 6881,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '871a411f-2668-41b2-b9c6-37353f86034f',
#   'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 46588,
#   'NewDeaths': 0,
#   'TotalDeaths': 155,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '02aaaa78-138a-462c-8059-2f78065990f0',
#   'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 103131,
#   'NewDeaths': 0,
#   'TotalDeaths': 1917,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '1a4c8291-bd3e-4765-ad5b-a77d8dbc7d8b',
#   'Country': 'Antarctica',
#   'CountryCode': 'AQ',
#   'Slug': 'antarctica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ddcb5dbf-a667-463e-8cb7-66688eca7aad',
#   'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9106,
#   'NewDeaths': 0,
#   'TotalDeaths': 146,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '06589228-670a-49af-a450-717bad44fa1d',
#   'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9718875,
#   'NewDeaths': 0,
#   'TotalDeaths': 129991,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e42e5253-a234-497e-9c36-094bcf46a9a9',
#   'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 445242,
#   'NewDeaths': 0,
#   'TotalDeaths': 8709,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'bc197fda-6c51-4ba2-8e45-543bf079b067',
#   'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 1713,
#   'TotalConfirmed': 10418986,
#   'NewDeaths': 0,
#   'TotalDeaths': 15786,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a6e7b1eb-b9d8-410c-a624-868162778e2a',
#   'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 4307,
#   'TotalConfirmed': 5462911,
#   'NewDeaths': 7,
#   'TotalDeaths': 21036,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3f8af6f0-056b-4217-9e28-015a64dc2a40',
#   'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 27,
#   'TotalConfirmed': 823496,
#   'NewDeaths': 2,
#   'TotalDeaths': 9955,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'c0aff4a2-b04e-42e9-bc8a-07fd3b00f3c4',
#   'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 37386,
#   'NewDeaths': 0,
#   'TotalDeaths': 833,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a2e01b05-c1e3-4c2a-9b0f-5f86940e4987',
#   'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 209,
#   'TotalConfirmed': 691509,
#   'NewDeaths': 0,
#   'TotalDeaths': 1529,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd517aaae-fd64-4a93-a241-be7c15cca4b9',
#   'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 37,
#   'TotalConfirmed': 2035782,
#   'NewDeaths': 0,
#   'TotalDeaths': 29425,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9383533c-e586-4b0b-9d3b-b10fdb7855e2',
#   'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 103424,
#   'NewDeaths': 0,
#   'TotalDeaths': 560,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '20a9c0b3-d491-4f63-9192-b988abf0ce6a',
#   'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 994037,
#   'NewDeaths': 0,
#   'TotalDeaths': 7118,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd11a3e35-b27d-4b06-b385-ed61fb43a643',
#   'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4617315,
#   'NewDeaths': 0,
#   'TotalDeaths': 32941,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0f8a6428-7767-4c06-9538-0cb92f43565b',
#   'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 68957,
#   'NewDeaths': 0,
#   'TotalDeaths': 687,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '197f3ac6-8f69-4992-9b63-007a3da3931d',
#   'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27782,
#   'NewDeaths': 0,
#   'TotalDeaths': 163,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a7a01d3a-60e6-4d99-91cf-eb434b8ca2ec',
#   'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 62380,
#   'NewDeaths': 0,
#   'TotalDeaths': 21,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ece97081-39a8-4cca-9cf4-9e34432beb91',
#   'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 52,
#   'TotalConfirmed': 1109581,
#   'NewDeaths': 1,
#   'TotalDeaths': 22240,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '367777d2-93bd-4117-9ee6-9c2c646f039f',
#   'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 400043,
#   'NewDeaths': 0,
#   'TotalDeaths': 16180,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8f99440c-b574-4c8a-993a-8b3914cfab99',
#   'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 326344,
#   'NewDeaths': 0,
#   'TotalDeaths': 2790,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0cafbd1b-378d-46ba-ba30-07eaa0d7789d',
#   'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 34849063,
#   'NewDeaths': 0,
#   'TotalDeaths': 688332,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3e105950-ade5-48e1-bd3b-5bb1242d09f8',
#   'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 241044,
#   'NewDeaths': 0,
#   'TotalDeaths': 225,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '651fc234-7eee-4192-a20c-b7e43922c0cc',
#   'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 571,
#   'TotalConfirmed': 1281155,
#   'NewDeaths': 13,
#   'TotalDeaths': 37916,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4da9ea91-c5dd-4021-9c2e-007309921b76',
#   'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21631,
#   'NewDeaths': 0,
#   'TotalDeaths': 387,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ce4d9628-1902-41c1-b955-826729fe5e11',
#   'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 50470,
#   'NewDeaths': 0,
#   'TotalDeaths': 38,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '41ff5416-9310-43f4-9a0c-f61bd5a32d7f',
#   'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 137995,
#   'NewDeaths': 0,
#   'TotalDeaths': 3056,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4e688249-aca0-45bd-b114-15c499d7ed65',
#   'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 123629,
#   'NewDeaths': 0,
#   'TotalDeaths': 1960,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'be1ad4f6-f982-400d-8fde-eeeefd7d98b3',
#   'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3770513,
#   'NewDeaths': 0,
#   'TotalDeaths': 41883,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0a23cb8e-4885-434f-8138-3398756cfd5e',
#   'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 24,
#   'TotalConfirmed': 62553,
#   'NewDeaths': 0,
#   'TotalDeaths': 410,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '6ea9dabe-83c1-4f0b-b442-8ed905edf14b',
#   'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15260,
#   'NewDeaths': 0,
#   'TotalDeaths': 113,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8f216beb-a7a0-4ee1-b800-fd51d3a62f29',
#   'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7627,
#   'NewDeaths': 0,
#   'TotalDeaths': 194,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3e1ad81c-cb00-4fd8-8ad5-2499fd27e949',
#   'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 8990,
#   'TotalConfirmed': 4786198,
#   'NewDeaths': 52,
#   'TotalDeaths': 61789,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ec077a18-41b7-42bf-a4a2-05ede9769ef8',
#   'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 5742,
#   'TotalConfirmed': 2207046,
#   'NewDeaths': 18,
#   'TotalDeaths': 15689,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8ae2f30b-a00a-4451-bda4-ae7c7c7ec7cd',
#   'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6310332,
#   'NewDeaths': 0,
#   'TotalDeaths': 141850,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'af5364e1-9f42-4486-ba68-fc847df3b479',
#   'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8762,
#   'NewDeaths': 0,
#   'TotalDeaths': 161,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '1c52d317-12b4-476b-93b4-9f9342737f31',
#   'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24837,
#   'NewDeaths': 0,
#   'TotalDeaths': 386,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ef25fc2c-2d8a-4784-a996-a5a39f5cb6bf',
#   'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 93219,
#   'NewDeaths': 0,
#   'TotalDeaths': 1445,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'f47cb825-7ef2-4ecd-af34-2cce3ecea4a1',
#   'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1138416,
#   'NewDeaths': 0,
#   'TotalDeaths': 9009,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '51e22188-dee0-42bb-aec3-effaa75ce28d',
#   'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 317,
#   'TotalConfirmed': 1248450,
#   'NewDeaths': 9,
#   'TotalDeaths': 17185,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a5b84758-e5e1-426b-b824-08aec061da9e',
#   'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 1111292,
#   'NewDeaths': 0,
#   'TotalDeaths': 8530,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '59f22aad-5853-47a4-b37d-776f36edaa08',
#   'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 602662,
#   'NewDeaths': 0,
#   'TotalDeaths': 1200,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '38d3bb0d-5234-4a29-a4eb-52a34e2ecb6a',
#   'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 641,
#   'TotalConfirmed': 4161566,
#   'NewDeaths': 13,
#   'TotalDeaths': 41648,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'dfc78275-5c72-41f1-a52f-9250862e1107',
#   'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 6,
#   'TotalConfirmed': 87830,
#   'NewDeaths': 0,
#   'TotalDeaths': 829,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '76d5218c-cbee-4728-904c-f5de26539487',
#   'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3384093,
#   'NewDeaths': 0,
#   'TotalDeaths': 7436,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '12f13db9-92e8-4d2f-8bff-46f6177f5072',
#   'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15690,
#   'NewDeaths': 0,
#   'TotalDeaths': 189,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a99b89be-deeb-494d-aa9e-ded428e06605',
#   'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15760,
#   'NewDeaths': 0,
#   'TotalDeaths': 74,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5559fd31-7431-4c7f-825e-57f22a805460',
#   'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 647425,
#   'NewDeaths': 0,
#   'TotalDeaths': 4384,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '59ca3cca-78b0-403c-9dd0-040e43f86393',
#   'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1009044,
#   'NewDeaths': 0,
#   'TotalDeaths': 35934,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '33e62ebc-b317-4e7d-8891-6d485c933255',
#   'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 515645,
#   'NewDeaths': 0,
#   'TotalDeaths': 24798,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '7bc68898-9901-49a4-bb3f-f97eaa76017e',
#   'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 201785,
#   'NewDeaths': 0,
#   'TotalDeaths': 4230,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '2c8c5fb0-6459-4519-96a1-65fe515bef51',
#   'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17174,
#   'NewDeaths': 0,
#   'TotalDeaths': 183,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a2510845-22fb-490c-8dfd-a1a104407a15',
#   'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10189,
#   'NewDeaths': 0,
#   'TotalDeaths': 103,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'fd05938c-0ef4-46be-b09d-f8edb0cb3ba6',
#   'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 607300,
#   'NewDeaths': 0,
#   'TotalDeaths': 2748,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '7eb9af60-cebc-4116-8439-481e2fe3a315',
#   'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 15,
#   'TotalConfirmed': 494039,
#   'NewDeaths': 0,
#   'TotalDeaths': 7572,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '15ebfd2d-b0a2-4777-ab90-ad04380280a8',
#   'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 68270,
#   'NewDeaths': 0,
#   'TotalDeaths': 878,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '2f199b63-5c45-4d8d-9e16-e27aabefc45b',
#   'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1360721,
#   'NewDeaths': 0,
#   'TotalDeaths': 6741,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a1eadcb1-6a2a-4e38-a512-fd63a069f959',
#   'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 37140238,
#   'NewDeaths': 0,
#   'TotalDeaths': 158317,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'cede6688-40d7-4d40-a5ff-7ddb7f36ac3f',
#   'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 48945,
#   'NewDeaths': 0,
#   'TotalDeaths': 306,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '226435ee-0454-42d4-9f1f-105de833e83a',
#   'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12580,
#   'NewDeaths': 0,
#   'TotalDeaths': 372,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '22876c22-3e43-4647-8412-2da93ac44f7c',
#   'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1785138,
#   'NewDeaths': 0,
#   'TotalDeaths': 16912,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '81811c57-e579-4f4b-8970-2e453635ad9e',
#   'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 35823771,
#   'NewDeaths': 0,
#   'TotalDeaths': 154535,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '547c2425-a8a8-4741-ae34-50d2a6ca0664',
#   'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 170894,
#   'NewDeaths': 0,
#   'TotalDeaths': 1460,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9ecbfd98-da52-4153-b330-c345ca9cc445',
#   'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5188890,
#   'NewDeaths': 0,
#   'TotalDeaths': 33750,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '074cccc2-f99f-438f-8ab4-b8eacacf185d',
#   'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 19604,
#   'NewDeaths': 0,
#   'TotalDeaths': 237,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '00a07eef-6b94-4cb3-90d6-fca90b21ae96',
#   'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 532,
#   'TotalConfirmed': 1142470,
#   'NewDeaths': 4,
#   'TotalDeaths': 19905,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd92e8a8e-619c-4cb5-bcfc-955298334b97',
#   'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 38047,
#   'NewDeaths': 0,
#   'TotalDeaths': 456,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '946a19e0-1589-4e03-a7a8-95bebcb1bbd9',
#   'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8848,
#   'NewDeaths': 0,
#   'TotalDeaths': 176,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3fdbbadc-77fa-4260-8a52-ed432afd3126',
#   'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 71443,
#   'NewDeaths': 0,
#   'TotalDeaths': 1281,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5e0c7dfe-6f6b-419c-9ce1-14f5a0ac4152',
#   'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 33828,
#   'NewDeaths': 0,
#   'TotalDeaths': 860,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'cf35df73-17ad-4591-aa8b-9d39670549ae',
#   'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '63c82b99-0b9b-47e7-a31c-cd2f37bb1096',
#   'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 457196,
#   'NewDeaths': 0,
#   'TotalDeaths': 11039,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '69b95a23-2425-4645-b39b-1a86a6de569e',
#   'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2141513,
#   'NewDeaths': 0,
#   'TotalDeaths': 47938,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'f3d2b47d-5c93-4e80-935d-bb8753601481',
#   'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 206571,
#   'NewDeaths': 0,
#   'TotalDeaths': 219,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '1d5712d3-c8ce-4aa5-8479-c44841a8e244',
#   'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 1132,
#   'TotalConfirmed': 44660579,
#   'NewDeaths': 14,
#   'TotalDeaths': 530500,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4c16e591-c9b2-4b3e-a268-fd953cbd83cc',
#   'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 4717,
#   'TotalConfirmed': 6517630,
#   'NewDeaths': 39,
#   'TotalDeaths': 158807,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '7127d445-d530-4d32-8709-d72e19f23399',
#   'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 76,
#   'TotalConfirmed': 7558078,
#   'NewDeaths': 5,
#   'TotalDeaths': 144592,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '58a2c385-ddb1-4375-a47b-decb7f97f638',
#   'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2461484,
#   'NewDeaths': 0,
#   'TotalDeaths': 25358,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '97c77732-093b-460a-9fa0-055c40f310ad',
#   'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1673665,
#   'NewDeaths': 0,
#   'TotalDeaths': 8066,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5809cf72-5a30-4e6b-9042-d257b9bfe49f',
#   'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 1530,
#   'TotalConfirmed': 4688662,
#   'NewDeaths': 0,
#   'TotalDeaths': 11767,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '993c432c-6228-4655-94c6-3b7e19146f42',
#   'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23642011,
#   'NewDeaths': 0,
#   'TotalDeaths': 179436,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e41e39b1-7559-4437-bfba-c3a81ca2361f',
#   'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 151931,
#   'NewDeaths': 0,
#   'TotalDeaths': 3320,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '267a6172-6734-4569-be91-05ab1da21e32',
#   'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 74170,
#   'TotalConfirmed': 22635975,
#   'NewDeaths': 72,
#   'TotalDeaths': 47087,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '57944ee5-ea8c-4985-9426-336c121396e5',
#   'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1746997,
#   'NewDeaths': 0,
#   'TotalDeaths': 14122,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9a8fde51-2934-4672-bdfd-59e3102ed151',
#   'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1484932,
#   'NewDeaths': 0,
#   'TotalDeaths': 19052,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8ace5b4b-dccf-4fdc-b57d-80ff47011a47',
#   'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 119,
#   'TotalConfirmed': 339671,
#   'NewDeaths': 0,
#   'TotalDeaths': 5678,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'cdfde09b-d69b-4788-a19c-7ae427586553',
#   'Country': 'Kiribati',
#   'CountryCode': 'KI',
#   'Slug': 'kiribati',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3430,
#   'NewDeaths': 0,
#   'TotalDeaths': 13,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'c1541fa5-64db-454c-adef-b2e00432fce6',
#   'Country': 'Korea (North)',
#   'CountryCode': 'KP',
#   'Slug': 'korea-north',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 6,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '77d3a6fb-1697-4253-a6db-af364274f8af',
#   'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 36675,
#   'TotalConfirmed': 25838239,
#   'NewDeaths': 18,
#   'TotalDeaths': 29372,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ccf75659-fc7d-4a27-b06a-c948bfdf92e1',
#   'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 662073,
#   'NewDeaths': 0,
#   'TotalDeaths': 2568,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '69d24fb6-e247-44f5-be9d-813b36e50f95',
#   'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 206452,
#   'NewDeaths': 0,
#   'TotalDeaths': 2991,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ec960afb-a7c5-447e-a711-bc62795726e3',
#   'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 216277,
#   'NewDeaths': 0,
#   'TotalDeaths': 758,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '1f63057a-de57-4bc0-8284-5ebc928a2f64',
#   'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 954230,
#   'NewDeaths': 0,
#   'TotalDeaths': 6062,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '77773eb1-adc8-4c41-8033-6d9c4af53337',
#   'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 79,
#   'TotalConfirmed': 1219066,
#   'NewDeaths': 1,
#   'TotalDeaths': 10712,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9865c46b-5153-407a-8e9e-b2a362cacd86',
#   'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 34490,
#   'NewDeaths': 0,
#   'TotalDeaths': 706,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '87c8f6e0-a48d-42c6-8ed2-e012d3275c7e',
#   'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7996,
#   'NewDeaths': 0,
#   'TotalDeaths': 294,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'dc7fae7a-b585-4888-89d3-bf1a630b5c95',
#   'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 507051,
#   'NewDeaths': 0,
#   'TotalDeaths': 6437,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd6f98a64-be24-4655-bb1e-f8cf2bbeec0d',
#   'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 20663,
#   'NewDeaths': 0,
#   'TotalDeaths': 87,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '429d015e-1c01-4478-8fb7-d1bec08e954b',
#   'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 1022,
#   'TotalConfirmed': 1269729,
#   'NewDeaths': 0,
#   'TotalDeaths': 9398,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'be53b2c8-0a2b-485e-9628-2ff0c0f9aef8',
#   'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 303025,
#   'NewDeaths': 0,
#   'TotalDeaths': 1147,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'cb534ed0-0d83-4f51-969c-adac019ccd78',
#   'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 344146,
#   'NewDeaths': 0,
#   'TotalDeaths': 9564,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5bf83b59-d01b-40e2-b620-940a485356e9',
#   'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 66749,
#   'NewDeaths': 0,
#   'TotalDeaths': 1411,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'b852cc77-18ce-4f51-8b0e-1740e379c245',
#   'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 88099,
#   'NewDeaths': 0,
#   'TotalDeaths': 2683,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd84a96b8-e2fe-40b3-9971-1d09fcba0281',
#   'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 4621,
#   'TotalConfirmed': 4923538,
#   'NewDeaths': 1,
#   'TotalDeaths': 36482,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'b5e329b7-95e8-4103-b779-c1cc2e24b21e',
#   'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 185364,
#   'NewDeaths': 0,
#   'TotalDeaths': 308,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ee4420ef-e7e8-4c4f-8201-4a5c3ff6603d',
#   'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 32738,
#   'NewDeaths': 0,
#   'TotalDeaths': 742,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'bbe600fd-8d39-4cdb-a353-fefdbd8319fe',
#   'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 12,
#   'TotalConfirmed': 115459,
#   'NewDeaths': 0,
#   'TotalDeaths': 808,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'b7507bb0-2e2e-48be-bfac-f371436b0a6f',
#   'Country': 'Marshall Islands',
#   'CountryCode': 'MH',
#   'Slug': 'marshall-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15389,
#   'NewDeaths': 0,
#   'TotalDeaths': 17,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '2ddaf770-97fe-4aeb-8537-47ec025c8135',
#   'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 63392,
#   'NewDeaths': 0,
#   'TotalDeaths': 997,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8f60a784-6617-42a3-86ea-8d2ea12fe454',
#   'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 265301,
#   'NewDeaths': 0,
#   'TotalDeaths': 1032,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '17569b10-33b5-4a83-9057-5f5c97a91b29',
#   'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7113658,
#   'NewDeaths': 0,
#   'TotalDeaths': 330424,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'f23e1195-8388-45b4-a8e8-0886a63a6d53',
#   'Country': 'Micronesia, Federated States of',
#   'CountryCode': 'FM',
#   'Slug': 'micronesia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22203,
#   'NewDeaths': 0,
#   'TotalDeaths': 55,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3eefd898-1de9-4551-a1b6-34b6b199f499',
#   'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 593816,
#   'NewDeaths': 0,
#   'TotalDeaths': 11894,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '08dcfa47-c7b1-488a-a474-1328e1074c91',
#   'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15005,
#   'NewDeaths': 0,
#   'TotalDeaths': 65,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '90b371af-506c-4070-bcb9-e10202b43a6c',
#   'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 985445,
#   'NewDeaths': 0,
#   'TotalDeaths': 2131,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'bbf28559-c704-4ef2-9335-483191ef62d0',
#   'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 44,
#   'TotalConfirmed': 283055,
#   'NewDeaths': 0,
#   'TotalDeaths': 2787,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e150b2f3-9917-44d0-8d77-a883655653d5',
#   'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 89,
#   'TotalConfirmed': 1265965,
#   'NewDeaths': 0,
#   'TotalDeaths': 16281,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4c8fac2f-cd6a-4623-9a4b-cde996899067',
#   'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 230475,
#   'NewDeaths': 0,
#   'TotalDeaths': 2224,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9796a74b-1f16-4180-9039-4a5fab38a8b7',
#   'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 90,
#   'TotalConfirmed': 632229,
#   'NewDeaths': 1,
#   'TotalDeaths': 19485,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e79b2dfa-8db5-4ad2-9af7-e0fead3b5900',
#   'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 169946,
#   'NewDeaths': 0,
#   'TotalDeaths': 4080,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ecb1e332-e992-40fa-96cd-fddf4aa2d9ad',
#   'Country': 'Nauru',
#   'CountryCode': 'NR',
#   'Slug': 'nauru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4611,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'dd38e720-df7e-400b-9f16-256dbd252a0f',
#   'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 10,
#   'TotalConfirmed': 1000708,
#   'NewDeaths': 0,
#   'TotalDeaths': 12019,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '287eb136-1a45-4313-adad-27e077aa4428',
#   'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8521599,
#   'NewDeaths': 0,
#   'TotalDeaths': 22846,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '98a0b0cb-a09d-4ccf-b26b-84a8fd083863',
#   'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1858163,
#   'NewDeaths': 0,
#   'TotalDeaths': 2107,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '93217416-c070-4de8-ab66-729df9430a98',
#   'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15186,
#   'NewDeaths': 0,
#   'TotalDeaths': 245,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '963ed236-fdaa-4b4d-81db-04cd0fb79b28',
#   'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9428,
#   'NewDeaths': 0,
#   'TotalDeaths': 314,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '2d396b7b-93f6-45da-bad4-56ca0cec2443',
#   'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 266192,
#   'NewDeaths': 0,
#   'TotalDeaths': 3155,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e12970b8-e99a-489f-ba5c-973be2ed1774',
#   'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 61,
#   'TotalConfirmed': 1465584,
#   'NewDeaths': 0,
#   'TotalDeaths': 4238,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e3aaf43c-6897-4dfe-ba8f-2335b672693c',
#   'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 398775,
#   'NewDeaths': 0,
#   'TotalDeaths': 4628,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '060392d1-ea66-4492-ac91-057f8be16931',
#   'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1574321,
#   'NewDeaths': 0,
#   'TotalDeaths': 30627,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4799a236-8626-4c42-be45-21467d1a92ce',
#   'Country': 'Palau',
#   'CountryCode': 'PW',
#   'Slug': 'palau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5513,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e0dacb8d-3dcd-4b33-932e-4dc280c037b9',
#   'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 703036,
#   'NewDeaths': 0,
#   'TotalDeaths': 5708,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0c8ff0d9-eb17-4d9f-9e1a-16c317b05256',
#   'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 990413,
#   'NewDeaths': 0,
#   'TotalDeaths': 8509,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '9c2fdd11-824c-49ab-8e55-c93ebabc60c5',
#   'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 45550,
#   'NewDeaths': 0,
#   'TotalDeaths': 668,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'fb8e42c2-77f5-4819-b8c3-ceea4288af11',
#   'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 717980,
#   'NewDeaths': 0,
#   'TotalDeaths': 19606,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3f5e513a-719f-4415-a5c8-2854ba40deff',
#   'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 2086,
#   'TotalConfirmed': 4161218,
#   'NewDeaths': 39,
#   'TotalDeaths': 217069,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '654e857c-6ac7-4fdc-b6d2-619804c30213',
#   'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 1232,
#   'TotalConfirmed': 4008550,
#   'NewDeaths': 29,
#   'TotalDeaths': 64240,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '6eb08649-ca41-4e9d-a47f-ddd51d0c8fb0',
#   'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 578,
#   'TotalConfirmed': 6343675,
#   'NewDeaths': 13,
#   'TotalDeaths': 118170,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4fc5c345-928e-4600-b030-5dc228ea2bcd',
#   'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5520731,
#   'NewDeaths': 0,
#   'TotalDeaths': 25228,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0ce6a858-f05f-4ed8-a2a8-5f3ecd2008a2',
#   'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 248,
#   'TotalConfirmed': 471004,
#   'NewDeaths': 0,
#   'TotalDeaths': 684,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '542709bc-4989-40e6-8eec-d204db994915',
#   'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 5,
#   'TotalConfirmed': 272179,
#   'NewDeaths': 0,
#   'TotalDeaths': 3202,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a5454d55-64d4-4e79-8d8b-fe8e970d8647',
#   'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 70,
#   'TotalConfirmed': 3288755,
#   'NewDeaths': 5,
#   'TotalDeaths': 67211,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8ada68bb-eb9b-471a-9662-81c46df955cc',
#   'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 5551,
#   'TotalConfirmed': 21154149,
#   'NewDeaths': 66,
#   'TotalDeaths': 382644,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'c43e58ca-907e-4f3c-b032-2ecb832c69f3',
#   'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 132584,
#   'NewDeaths': 0,
#   'TotalDeaths': 1467,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '7a59749e-c421-489c-8954-9caf5ff60996',
#   'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6549,
#   'NewDeaths': 0,
#   'TotalDeaths': 46,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4863b441-d249-44b5-a83b-1d576e55d83c',
#   'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29654,
#   'NewDeaths': 0,
#   'TotalDeaths': 407,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '1d9601da-2216-4c05-86b7-9cd7b085ef73',
#   'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9459,
#   'NewDeaths': 0,
#   'TotalDeaths': 116,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '136efa2b-e9e2-421e-b239-f171a7b179ad',
#   'Country': 'Samoa',
#   'CountryCode': 'WS',
#   'Slug': 'samoa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15946,
#   'NewDeaths': 0,
#   'TotalDeaths': 29,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ea557877-63ed-4194-8d90-2e0d9217d3ca',
#   'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21662,
#   'NewDeaths': 0,
#   'TotalDeaths': 119,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a373b2a6-3ee0-46fc-ac1d-2244526e239d',
#   'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6270,
#   'NewDeaths': 0,
#   'TotalDeaths': 77,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '65d281ba-9732-4520-a28d-3afab8b188b6',
#   'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 106,
#   'TotalConfirmed': 823494,
#   'NewDeaths': 1,
#   'TotalDeaths': 9417,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '0335a78c-3077-4ece-9596-dcda1095dd56',
#   'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 88679,
#   'NewDeaths': 0,
#   'TotalDeaths': 1968,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '383479bd-844f-4bab-b3f6-787c20ac6a0d',
#   'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 535,
#   'TotalConfirmed': 2408130,
#   'NewDeaths': 5,
#   'TotalDeaths': 17275,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '188e8922-2405-48a2-84a8-81140f70463c',
#   'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 49380,
#   'NewDeaths': 0,
#   'TotalDeaths': 171,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'edec13a9-913c-4839-b58c-912a0abc6b61',
#   'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7754,
#   'NewDeaths': 0,
#   'TotalDeaths': 126,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'c68aaa6f-98e8-4f64-a5e2-d6c9d2f0f404',
#   'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 2686,
#   'TotalConfirmed': 2121435,
#   'NewDeaths': 1,
#   'TotalDeaths': 1686,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4a4ee97d-7ce1-4a02-a6be-72cab4003559',
#   'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 357,
#   'TotalConfirmed': 2644984,
#   'NewDeaths': 5,
#   'TotalDeaths': 20629,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '7103849b-f731-4b40-9599-ef7c9ec61815',
#   'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 837,
#   'TotalConfirmed': 1237624,
#   'NewDeaths': 1,
#   'TotalDeaths': 6893,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '4ffe62dd-cd5d-4a1c-b13a-80b14b9e9cad',
#   'Country': 'Solomon Islands',
#   'CountryCode': 'SB',
#   'Slug': 'solomon-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21544,
#   'NewDeaths': 0,
#   'TotalDeaths': 153,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '6d4792dc-94aa-4e30-ae61-f563b8044ac6',
#   'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27243,
#   'NewDeaths': 0,
#   'TotalDeaths': 1361,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '16282426-7189-4b2d-aeaf-b2a83a0791e6',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4029737,
#   'NewDeaths': 0,
#   'TotalDeaths': 102363,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a5444799-eda8-4a09-8a5c-9b9810bc1c74',
#   'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 18318,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '48042420-60e3-4bd0-a05a-4a57a5377acd',
#   'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13529643,
#   'NewDeaths': 0,
#   'TotalDeaths': 115239,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ce0bcee7-1650-47bb-9cf6-f049b5c37ea5',
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 10,
#   'TotalConfirmed': 671320,
#   'NewDeaths': 0,
#   'TotalDeaths': 16782,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '6337b463-66fa-4b04-a4cd-836cfc2979be',
#   'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 63509,
#   'NewDeaths': 0,
#   'TotalDeaths': 4972,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e211deb6-7b80-4c3a-b473-ab889a2dfbda',
#   'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 81228,
#   'NewDeaths': 0,
#   'TotalDeaths': 1392,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'fe2b5af4-15bb-4831-97b2-537eac1c9530',
#   'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 73558,
#   'NewDeaths': 0,
#   'TotalDeaths': 1422,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '44d5a281-2752-4e56-bd8d-41299f5d24ce',
#   'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2614997,
#   'NewDeaths': 0,
#   'TotalDeaths': 20753,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '53b6e645-4068-4de1-bbe3-7d7521abd3f2',
#   'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4255891,
#   'NewDeaths': 0,
#   'TotalDeaths': 14081,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '93269819-245d-4364-97ac-c82994951c3a',
#   'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 57367,
#   'NewDeaths': 0,
#   'TotalDeaths': 3163,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a580ee90-1c8d-4252-9ca3-79353619ab14',
#   'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 25535,
#   'TotalConfirmed': 7863193,
#   'NewDeaths': 67,
#   'TotalDeaths': 13151,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '8d4c2d29-ce29-4209-9eeb-d129f8cc3cd1',
#   'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17786,
#   'NewDeaths': 0,
#   'TotalDeaths': 125,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'f495e91c-2d4d-4659-84f1-0142b5085ea8',
#   'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 40054,
#   'NewDeaths': 0,
#   'TotalDeaths': 845,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '07558186-d080-4678-972d-55644fbead18',
#   'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4692448,
#   'NewDeaths': 0,
#   'TotalDeaths': 32955,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '82901cbf-af80-4dde-8d31-6393ffa2d8e8',
#   'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23303,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5e066d2d-c42b-44e5-acb5-0382f51ddef5',
#   'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39310,
#   'NewDeaths': 0,
#   'TotalDeaths': 290,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a03f56ca-845f-4b58-a7e9-5cbb88ea6292',
#   'Country': 'Tonga',
#   'CountryCode': 'TO',
#   'Slug': 'tonga',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16182,
#   'NewDeaths': 0,
#   'TotalDeaths': 12,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'e10544a0-49aa-4116-a9c0-49ef6c37d393',
#   'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 184854,
#   'NewDeaths': 0,
#   'TotalDeaths': 4255,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '78d8c540-924e-43af-8f2b-cba91aa01464',
#   'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1146593,
#   'NewDeaths': 0,
#   'TotalDeaths': 29259,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'd6432ea2-2a08-445f-95b6-e646f32ec4ff',
#   'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16919638,
#   'NewDeaths': 0,
#   'TotalDeaths': 101203,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'c1f1615e-e8e3-46f5-af39-89898cd58584',
#   'Country': 'Tuvalu',
#   'CountryCode': 'TV',
#   'Slug': 'tuvalu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '812aebf7-34d7-447d-9144-96c5327db8b1',
#   'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 169473,
#   'NewDeaths': 0,
#   'TotalDeaths': 3630,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '2d247771-78cf-435d-9bae-e4b1c75e9487',
#   'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 66,
#   'TotalConfirmed': 5617767,
#   'NewDeaths': 1,
#   'TotalDeaths': 118068,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '3623993f-3c75-4da0-a84a-2161639152f4',
#   'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 274,
#   'TotalConfirmed': 1039090,
#   'NewDeaths': 0,
#   'TotalDeaths': 2348,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '48fdf360-a56d-41a6-9a50-d686354e5a22',
#   'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24155154,
#   'NewDeaths': 0,
#   'TotalDeaths': 210680,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '6147d235-c5b0-4467-b38f-5d7fbc76adfa',
#   'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 4608,
#   'TotalConfirmed': 97734261,
#   'NewDeaths': 21,
#   'TotalDeaths': 1072582,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '28eb990e-8c62-4378-8401-cc4133c18603',
#   'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 990560,
#   'NewDeaths': 0,
#   'TotalDeaths': 7518,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5a06c8d9-7f9c-45d6-9236-feb0dd12426c',
#   'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 244739,
#   'NewDeaths': 0,
#   'TotalDeaths': 1637,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'a941d696-921b-442a-92e7-28b5d8d099f1',
#   'Country': 'Vanuatu',
#   'CountryCode': 'VU',
#   'Slug': 'vanuatu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11981,
#   'NewDeaths': 0,
#   'TotalDeaths': 14,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'b541bcd5-3b2d-40fd-a500-2c73edf3fd20',
#   'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 84,
#   'TotalConfirmed': 546047,
#   'NewDeaths': 1,
#   'TotalDeaths': 5821,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'b2e135f2-0c6c-4146-bd6a-8b8d5cf67adb',
#   'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 359,
#   'TotalConfirmed': 11505608,
#   'NewDeaths': 0,
#   'TotalDeaths': 43165,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'addf66b1-f367-4cce-b06c-8c2a0bee3617',
#   'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11945,
#   'NewDeaths': 0,
#   'TotalDeaths': 2159,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': '5e718567-6d3f-49a5-888d-b1713370f304',
#   'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 333685,
#   'NewDeaths': 0,
#   'TotalDeaths': 4017,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}},
#  {'ID': 'ff8a0480-f7d9-48d9-891a-0822381fd03d',
#   'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 257893,
#   'NewDeaths': 0,
#   'TotalDeaths': 5606,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-11-06T22:55:06.135Z',
#   'Premium': {}}]

# %% [markdown]
# # 1. Converting JSON to Tabluar format

# %% [markdown]
# Converting JSON response from the API to Dataframe as the data from Dataframe is easy to process.

# %%
df_covid = pd.DataFrame.from_dict(json_countries)

# %%
df_covid.head()
# Out:
#                                      ID      Country CountryCode         Slug  \
# 0  0b096549-975a-46db-be84-1895d73dfaf7  Afghanistan          AF  afghanistan
# 1  ceb74727-4765-46cc-b538-088efb38e47f      Albania          AL      albania
# 2  fb7c55ee-39f2-4d6d-be32-dc254b0fd257      Algeria          DZ      algeria
# 3  871a411f-2668-41b2-b9c6-37353f86034f      Andorra          AD      andorra
# 4  02aaaa78-138a-462c-8059-2f78065990f0       Angola          AO       angola
#
#    NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0            77          203574          1         7826             0
# 1            19          333046          0         3593             0
# 2             6          270862          0         6881             0
# 3             0           46588          0          155             0
# 4             0          103131          0         1917             0
#
#    TotalRecovered                      Date Premium
# 0               0  2022-11-06T22:55:06.135Z      {}
# 1               0  2022-11-06T22:55:06.135Z      {}
# 2               0  2022-11-06T22:55:06.135Z      {}
# 3               0  2022-11-06T22:55:06.135Z      {}
# 4               0  2022-11-06T22:55:06.135Z      {}

# %% [markdown]
# # 2. Drop Columns

# %% [markdown]
# Dropping the columns ID, Slug and Premium because of the below reasons:
# 1.ID - ID is a unique value for each record and we do not need that for data analysis
# 2.Slug - the value of slug is same as Country. Only difference is slug is lower case of Country
# 2.Premium - Premium has no values as we are not using premium services of this API.

# %%
df_covid = df_covid.drop(['ID','Slug','Premium'], axis=1)

# %%
df_covid.head()
# Out:
#        Country CountryCode  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0  Afghanistan          AF            77          203574          1
# 1      Albania          AL            19          333046          0
# 2      Algeria          DZ             6          270862          0
# 3      Andorra          AD             0           46588          0
# 4       Angola          AO             0          103131          0
#
#    TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0         7826             0               0  2022-11-06T22:55:06.135Z
# 1         3593             0               0  2022-11-06T22:55:06.135Z
# 2         6881             0               0  2022-11-06T22:55:06.135Z
# 3          155             0               0  2022-11-06T22:55:06.135Z
# 4         1917             0               0  2022-11-06T22:55:06.135Z

# %% [markdown]
# # 3. Replace the Headers

# %% [markdown]
# Replacing the headers to match the Python standards and also to match the format of other datasources in Milestone 2 and Milestone 3.

# %%
df_covid.rename(columns={'Country': 'country', 'CountryCode': 'country_code','NewConfirmed': 'new_confirmed', 'TotalConfirmed': 'total_confirmed','NewDeaths':'new_deaths','TotalDeaths':'total_deaths','NewRecovered':'new_recovered','TotalRecovered':'total_recovered','Date':'date'}, inplace=True)

# %%
df_covid
# Out:
#                              country country_code  new_confirmed  \
# 0                        Afghanistan           AF             77
# 1                            Albania           AL             19
# 2                            Algeria           DZ              6
# 3                            Andorra           AD              0
# 4                             Angola           AO              0
# ..                               ...          ...            ...
# 192  Venezuela (Bolivarian Republic)           VE             84
# 193                         Viet Nam           VN            359
# 194                            Yemen           YE              0
# 195                           Zambia           ZM              0
# 196                         Zimbabwe           ZW              0
#
#      total_confirmed  new_deaths  total_deaths  new_recovered  \
# 0             203574           1          7826              0
# 1             333046           0          3593              0
# 2             270862           0          6881              0
# 3              46588           0           155              0
# 4             103131           0          1917              0
# ..               ...         ...           ...            ...
# 192           546047           1          5821              0
# 193         11505608           0         43165              0
# 194            11945           0          2159              0
# 195           333685           0          4017              0
# 196           257893           0          5606              0
#
#      total_recovered                      date
# 0                  0  2022-11-06T22:55:06.135Z
# 1                  0  2022-11-06T22:55:06.135Z
# 2                  0  2022-11-06T22:55:06.135Z
# 3                  0  2022-11-06T22:55:06.135Z
# 4                  0  2022-11-06T22:55:06.135Z
# ..               ...                       ...
# 192                0  2022-11-06T22:55:06.135Z
# 193                0  2022-11-06T22:55:06.135Z
# 194                0  2022-11-06T22:55:06.135Z
# 195                0  2022-11-06T22:55:06.135Z
# 196                0  2022-11-06T22:55:06.135Z
#
# [197 rows x 9 columns]

# %% [markdown]
# # 4. Fix casing for columns with string data type

# %% [markdown]
# Converting the country name to upper case so that when we work 2 other datasets, it will be easy with merging the datasets based on country name

# %%
df_covid['country'] = df_covid['country'].str.upper()

# %%
df_covid
# Out:
#                              country country_code  new_confirmed  \
# 0                        AFGHANISTAN           AF             77
# 1                            ALBANIA           AL             19
# 2                            ALGERIA           DZ              6
# 3                            ANDORRA           AD              0
# 4                             ANGOLA           AO              0
# ..                               ...          ...            ...
# 192  VENEZUELA (BOLIVARIAN REPUBLIC)           VE             84
# 193                         VIET NAM           VN            359
# 194                            YEMEN           YE              0
# 195                           ZAMBIA           ZM              0
# 196                         ZIMBABWE           ZW              0
#
#      total_confirmed  new_deaths  total_deaths  new_recovered  \
# 0             203574           1          7826              0
# 1             333046           0          3593              0
# 2             270862           0          6881              0
# 3              46588           0           155              0
# 4             103131           0          1917              0
# ..               ...         ...           ...            ...
# 192           546047           1          5821              0
# 193         11505608           0         43165              0
# 194            11945           0          2159              0
# 195           333685           0          4017              0
# 196           257893           0          5606              0
#
#      total_recovered                      date
# 0                  0  2022-11-06T22:55:06.135Z
# 1                  0  2022-11-06T22:55:06.135Z
# 2                  0  2022-11-06T22:55:06.135Z
# 3                  0  2022-11-06T22:55:06.135Z
# 4                  0  2022-11-06T22:55:06.135Z
# ..               ...                       ...
# 192                0  2022-11-06T22:55:06.135Z
# 193                0  2022-11-06T22:55:06.135Z
# 194                0  2022-11-06T22:55:06.135Z
# 195                0  2022-11-06T22:55:06.135Z
# 196                0  2022-11-06T22:55:06.135Z
#
# [197 rows x 9 columns]

# %% [markdown]
# # 5. Change data types of the columns

# %%
df_covid.head()
# Out:
#        country country_code  new_confirmed  total_confirmed  new_deaths  \
# 0  AFGHANISTAN           AF             77           203574           1
# 1      ALBANIA           AL             19           333046           0
# 2      ALGERIA           DZ              6           270862           0
# 3      ANDORRA           AD              0            46588           0
# 4       ANGOLA           AO              0           103131           0
#
#    total_deaths  new_recovered  total_recovered                      date
# 0          7826              0                0  2022-11-06T22:55:06.135Z
# 1          3593              0                0  2022-11-06T22:55:06.135Z
# 2          6881              0                0  2022-11-06T22:55:06.135Z
# 3           155              0                0  2022-11-06T22:55:06.135Z
# 4          1917              0                0  2022-11-06T22:55:06.135Z

# %% [markdown]
# We will be changing date format to YYYY-MM-dd to match with other dataframes.

# %%
df_covid['date'] = pd.to_datetime(df_covid['date'])
df_covid['date'] = df_covid.date.dt.strftime('%Y-%m-%d')

# %%
df_covid.head()
# Out:
#        country country_code  new_confirmed  total_confirmed  new_deaths  \
# 0  AFGHANISTAN           AF             77           203574           1
# 1      ALBANIA           AL             19           333046           0
# 2      ALGERIA           DZ              6           270862           0
# 3      ANDORRA           AD              0            46588           0
# 4       ANGOLA           AO              0           103131           0
#
#    total_deaths  new_recovered  total_recovered        date
# 0          7826              0                0  2022-11-06
# 1          3593              0                0  2022-11-06
# 2          6881              0                0  2022-11-06
# 3           155              0                0  2022-11-06
# 4          1917              0                0  2022-11-06

# %% [markdown]
# # 6. Drop duplicates

# %% [markdown]
# Manually, with lesser data we might be able to identify the duplicates. But when we run this program regularly and the data gets updated and a case where we can find duplicates on nth day of program run, we can get bad results. So, I would like to handle it programatically.

# %%
df_covid
# Out:
#                              country country_code  new_confirmed  \
# 0                        AFGHANISTAN           AF             77
# 1                            ALBANIA           AL             19
# 2                            ALGERIA           DZ              6
# 3                            ANDORRA           AD              0
# 4                             ANGOLA           AO              0
# ..                               ...          ...            ...
# 192  VENEZUELA (BOLIVARIAN REPUBLIC)           VE             84
# 193                         VIET NAM           VN            359
# 194                            YEMEN           YE              0
# 195                           ZAMBIA           ZM              0
# 196                         ZIMBABWE           ZW              0
#
#      total_confirmed  new_deaths  total_deaths  new_recovered  \
# 0             203574           1          7826              0
# 1             333046           0          3593              0
# 2             270862           0          6881              0
# 3              46588           0           155              0
# 4             103131           0          1917              0
# ..               ...         ...           ...            ...
# 192           546047           1          5821              0
# 193         11505608           0         43165              0
# 194            11945           0          2159              0
# 195           333685           0          4017              0
# 196           257893           0          5606              0
#
#      total_recovered        date
# 0                  0  2022-11-06
# 1                  0  2022-11-06
# 2                  0  2022-11-06
# 3                  0  2022-11-06
# 4                  0  2022-11-06
# ..               ...         ...
# 192                0  2022-11-06
# 193                0  2022-11-06
# 194                0  2022-11-06
# 195                0  2022-11-06
# 196                0  2022-11-06
#
# [197 rows x 9 columns]

# %%
df_covid = df_covid.drop_duplicates()

# %%
df_covid
# Out:
#                              country country_code  new_confirmed  \
# 0                        AFGHANISTAN           AF             77
# 1                            ALBANIA           AL             19
# 2                            ALGERIA           DZ              6
# 3                            ANDORRA           AD              0
# 4                             ANGOLA           AO              0
# ..                               ...          ...            ...
# 192  VENEZUELA (BOLIVARIAN REPUBLIC)           VE             84
# 193                         VIET NAM           VN            359
# 194                            YEMEN           YE              0
# 195                           ZAMBIA           ZM              0
# 196                         ZIMBABWE           ZW              0
#
#      total_confirmed  new_deaths  total_deaths  new_recovered  \
# 0             203574           1          7826              0
# 1             333046           0          3593              0
# 2             270862           0          6881              0
# 3              46588           0           155              0
# 4             103131           0          1917              0
# ..               ...         ...           ...            ...
# 192           546047           1          5821              0
# 193         11505608           0         43165              0
# 194            11945           0          2159              0
# 195           333685           0          4017              0
# 196           257893           0          5606              0
#
#      total_recovered        date
# 0                  0  2022-11-06
# 1                  0  2022-11-06
# 2                  0  2022-11-06
# 3                  0  2022-11-06
# 4                  0  2022-11-06
# ..               ...         ...
# 192                0  2022-11-06
# 193                0  2022-11-06
# 194                0  2022-11-06
# 195                0  2022-11-06
# 196                0  2022-11-06
#
# [197 rows x 9 columns]

# %% [markdown]
# # 7. Remove the columns

# %% [markdown]
# Removing columns which has value has zero as it has not value for analysis.

# %%
df_covid = df_covid.replace(0,np.nan).dropna(axis=1,how="all")

# %%
df_covid
# Out:
#                              country country_code  new_confirmed  \
# 0                        AFGHANISTAN           AF           77.0
# 1                            ALBANIA           AL           19.0
# 2                            ALGERIA           DZ            6.0
# 3                            ANDORRA           AD            NaN
# 4                             ANGOLA           AO            NaN
# ..                               ...          ...            ...
# 192  VENEZUELA (BOLIVARIAN REPUBLIC)           VE           84.0
# 193                         VIET NAM           VN          359.0
# 194                            YEMEN           YE            NaN
# 195                           ZAMBIA           ZM            NaN
# 196                         ZIMBABWE           ZW            NaN
#
#      total_confirmed  new_deaths  total_deaths        date
# 0             203574         1.0        7826.0  2022-11-06
# 1             333046         NaN        3593.0  2022-11-06
# 2             270862         NaN        6881.0  2022-11-06
# 3              46588         NaN         155.0  2022-11-06
# 4             103131         NaN        1917.0  2022-11-06
# ..               ...         ...           ...         ...
# 192           546047         1.0        5821.0  2022-11-06
# 193         11505608         NaN       43165.0  2022-11-06
# 194            11945         NaN        2159.0  2022-11-06
# 195           333685         NaN        4017.0  2022-11-06
# 196           257893         NaN        5606.0  2022-11-06
#
# [197 rows x 7 columns]

# %% [markdown]
#  Upon performing the above function, we have removed new_recovered and total_recovered as they have zero as its value for all the rows.

# %% [markdown]
# # Ethical Implications of Data Wrangling:

# %% [markdown]
# I have used COVID deaths and cases from a Public API and the data posted is visible to the public. Ethical implications of data wrangling of Public API data:
#
# 1. As we access data from the APIL directly, this increases number of hits on the server which will have performance issues on the API and can bring down the API as the TPS will be increased.
#
# 2. As we are unsure about the data source for this data, we can not confirm if the data is accurate
#
# 3. As we are performing some clean-up and transformations, we might change some data and data being used in our analysis might be slightly different from source data.
#
# 4. As this API also has premium access and current data fetch doesnt need any authorization, as there is no authorizations required, we can be sure that they dont expose sensitive data.
#
# As this is a public API, we shouldn't have any legal complications. However, the data wrangling from this source has implications of accuracy and performance issues on the API.

# %% [markdown]
# # Steps Completed:

# %% [markdown]
# I have completed below steps:
#
#     1. Drop Columns
#
#     2. Replace Headers
#
#     3. Fix casing for columns with string data type
#
#     4. Change data types of the columns
#
#     5. Drop duplicates
#
#     6. Remove the columns
